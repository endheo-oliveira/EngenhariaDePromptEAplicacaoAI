# %% [markdown]
# <a href="https://colab.research.google.com/github/endheo-oliveira/EngenhariaDePromptEAplicacaoAI/blob/main/MiniProjetoCalculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ATIVIDADE PROGRAMAÇÃO
#
# Nome: Endheo Rodrigues - (Ciencia da computação)3FERIA
#
# **CALCULADORA SIMPLES**

# %%
#usuario digita dois numeros
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

#usuario escolhe qual vai ser a operação
operacao = input("Digite a operação (+, -, *, /): ")

#Busca operador digitado pelo usuario
operadores = {
    '+': lambda a, b: a + b,
    '-': lambda a, b: a - b,
    '*': lambda a, b: a * b,
    '/': lambda a, b: a / b,
}
#Se operador tiver no dicionario operadores vai executar o calculo
if operacao in operadores:
    num = operadores[operacao](num1, num2)
    print("O resultado da operação:", num)
#Se não o codigo encerra
else:
    print("Operação inválida")
